# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

deepfake_types = ['Deepfakes', 'Face2Face', 'FaceShifter', 'FaceSwap', 'NeuralTextures']

# Convert data to a numpy array for heatmap
labels = list(deepfake_types)
values = np.array([
    [0.8683, 0.5804, 0.5374, 0.4642, 0.6279],  # deepfake
    [0.6353, 0.8096, 0.4923, 0.5343, 0.6062],  # face2face
    [0.5982, 0.5147, 0.8288, 0.4886, 0.5798],  # faceshifter
    [0.5027, 0.5328, 0.4967, 0.8440, 0.4858],  # faceswap
    [0.7139, 0.6367, 0.6059, 0.4814, 0.7968]   # neuraltextures
])


# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(values, annot=True, cmap="YlGnBu", xticklabels=deepfake_types, yticklabels=deepfake_types, fmt=".4f")
plt.title("Model Accuracy against Datasets (EfficientNet-B0)")
plt.xlabel("Dataset Type")
plt.ylabel("Model Type")
plt.show()

# knowledge distillation type learning
# soumik benchmark on company deepfake detector - because detectors are created on model structure
# note down amount of training data in the test set and dataset
# different loss functions - focal loss, 
# implement federated learning averaging gradients function logic
# foundational model for all datasets
# check other models

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Example data
deepfake_types = ['Deepfakes', 'Face2Face', 'FaceShifter', 'FaceSwap', 'NeuralTextures']
values = [0.7525, 0.6939, 0.6805, 0.6703, 0.6840]

# Reshape values to a 2D array for the heatmap
values_2d = np.array(values).reshape(1, -1)

# Create the 1D heatmap
plt.figure(figsize=(10, 2))  # Adjust the size for a horizontal layout
sns.heatmap(values_2d, annot=True, cmap="YlGnBu", xticklabels=deepfake_types, yticklabels=["Accuracy"], fmt=".4f", cbar=True)

# Title and labels
plt.title("Model Accuracy across Datasets (XceptionNet)")
plt.xlabel("Dataset")
plt.ylabel("")  # Remove the label for the y-axis since there's only one row

# Show the heatmap
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Example data
deepfake_types = ['Deepfakes', 'Face2Face', 'FaceShifter', 'FaceSwap', 'NeuralTextures']
values = [0.7244, 0.6233, 0.5823, 0.5230, 0.6378]

# Reshape values to a 2D array for the heatmap
values_2d = np.array(values).reshape(1, -1)

# Create the 1D heatmap
plt.figure(figsize=(10, 2))  # Adjust the size for a horizontal layout
sns.heatmap(values_2d, annot=True, cmap="YlGnBu", xticklabels=deepfake_types, yticklabels=["Accuracy"], fmt=".4f", cbar=True)

# Title and labels
plt.title("Majority Voting Ensemble Accuracy across Datasets (XceptionNet)")
plt.xlabel("Dataset")
plt.ylabel("")  # Remove the label for the y-axis since there's only one row

# Show the heatmap
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Example data
deepfake_types = ['Deepfakes', 'Face2Face', 'FaceShifter', 'FaceSwap', 'NeuralTextures']
values = [0.6680, 0.5585, 0.5541, 0.4980, 0.5816]

# Reshape values to a 2D array for the heatmap
values_2d = np.array(values).reshape(1, -1)

# Create the 1D heatmap
plt.figure(figsize=(10, 2))  # Adjust the size for a horizontal layout
sns.heatmap(values_2d, annot=True, cmap="YlGnBu", xticklabels=deepfake_types, yticklabels=["Accuracy"], fmt=".4f", cbar=True)

# Title and labels
plt.title("Averaging Ensemble Accuracy across Datasets (XceptionNet)")
plt.xlabel("Dataset")
plt.ylabel("")  # Remove the label for the y-axis since there's only one row

# Show the heatmap
plt.show()
